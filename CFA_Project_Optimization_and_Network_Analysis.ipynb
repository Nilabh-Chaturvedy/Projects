# %%
#installing the libraries
#pip install geopy
#pip install pulp
#pip install networkx

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
from geopy.geocoders import Nominatim
from geopy.point import Point
from pulp import *
import geopy.distance

# %%
#Reading the data
df=pd.read_csv('uber.csv')

# %%
#Displaying the data
df.head()
# Out:
#       Index      key  fare_amount          pickup_datetime  pickup_longitude  \
# 0  35242813  09:47.0         22.5  2015-01-01 00:09:47 UTC        -73.990059
# 1  27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2  44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3  25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4  17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC        -73.925023
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.757221         -73.999512         40.723217                1
# 1        40.728225         -73.994710         40.750325                1
# 2        40.740770         -73.962565         40.772647                1
# 3        40.790844         -73.965316         40.803349                3
# 4        40.744085         -73.973082         40.761247                5

# %%
#Shape of the data
df.shape
# Out:
# (200000, 9)

# %%
#Filtering the dataset for Jan,2015
df=df[(df.pickup_datetime>='2015-01-01 00:00:00 UTC') & (df.pickup_datetime<='2015-01-31 00:00:00 UTC')]

# %%
#Creating pickup and dropoff coordinates
df['geom_pick'] = df.apply(lambda row: (str(row.pickup_latitude),str(row.pickup_longitude)),axis=1)
df['geom_drop'] = df.apply(lambda row: (str(row.dropoff_latitude),str(row.dropoff_longitude)),axis=1)

# %%
#Calulating distance in miles based on pick up and dropoff coordinates
df['distance'] = df.apply(lambda x: geopy.distance.distance(x.geom_drop,x.geom_pick).miles, axis=1)

# %%
#Extracting address from the coordinates(takes time to run)
geolocator = Nominatim(user_agent="geoapiExercises")
df['pickup_location'] = df.apply(lambda row: geolocator.reverse(row.geom_pick).address,axis=1)
df['drop_location'] = df.apply(lambda row: geolocator.reverse(row.geom_drop).address,axis=1)

# %%
#Standardising the pick up and drop
df['pick']=df['pickup_location'].str.split(",",-1,expand=True)[0]+df['pickup_location'].str.split(",",-1,expand=True)[1]+df['pickup_location'].str.split(",",-1,expand=True)[2]
df['dropoff']=df['drop_location'].str.split(",",-1,expand=True)[0]+df['drop_location'].str.split(",",-1,expand=True)[1]+df['drop_location'].str.split(",",-1,expand=True)[2]

# %%
df.head()
# Out:
#        Index      key  fare_amount          pickup_datetime  pickup_longitude  \
# 0   35242813  09:47.0         22.5  2015-01-01 00:09:47 UTC        -73.990059
# 10  51300077  15:31.0          9.5  2015-01-01 00:15:31 UTC        -73.985649
# 18  41247972  20:44.0          6.0  2015-01-01 00:20:44 UTC        -73.995056
# 21  41138301  47:06.0          5.5  2015-01-01 00:47:06 UTC        -74.002419
# 47  13349674  51:07.0          6.0  2015-01-01 00:51:07 UTC        -73.985779
#
#     pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0         40.757221         -73.999512         40.723217                1
# 10        40.747444         -73.988586         40.729805                1
# 18        40.765320         -73.974457         40.753860                1
# 21        40.733700         -73.987282         40.720634                2
# 47        40.722897         -73.984879         40.760651                1
#
#                       geom_pick                    geom_drop  distance  \
# 0    (40.75722122, -73.9900589)  (40.72321701, -73.99951172)  2.398255
# 10  (40.74744415, -73.98564911)  (40.72980499, -73.98858643)  1.226872
# 18  (40.76531982, -73.99505615)  (40.75386047, -73.97445679)  1.339188
# 21   (40.7336998, -74.00241852)   (40.72063446, -73.9872818)  1.201727
# 47  (40.72289658, -73.98577881)  (40.76065063, -73.98487854)  2.605556
#
#                                       pickup_location  \
# 0   Port Authority Bus Terminal, 625, 8th Avenue, ...
# 10  320, 5th Avenue, Manhattan Community Board 5, ...
# 18  49 St Deli & Coffee House, 682, 11th Avenue, M...
# 21  59, Christopher Street, Manhattan Community Bo...
# 47  20, Avenue A, Manhattan Community Board 3, Man...
#
#                                         drop_location  \
# 0   Alo Yoga, 96, Spring Street, Manhattan Communi...
# 10  Barney Building, 227, East 9th Street, Manhatt...
# 18  Grand Central Terminal, Park Avenue, Manhattan...
# 21  147, Essex Street, Manhattan Community Board 3...
# 47  Crowne Plaza Times Square, 1605, Broadway, Tim...
#
#                                                  pick  \
# 0          Port Authority Bus Terminal 625 8th Avenue
# 10         320 5th Avenue Manhattan Community Board 5
# 18          49 St Deli & Coffee House 682 11th Avenue
# 21  59 Christopher Street Manhattan Community Board 2
# 47            20 Avenue A Manhattan Community Board 3
#
#                                               dropoff
# 0                           Alo Yoga 96 Spring Street
# 10                Barney Building 227 East 9th Street
# 18  Grand Central Terminal Park Avenue Manhattan C...
# 21       147 Essex Street Manhattan Community Board 3
# 47            Crowne Plaza Times Square 1605 Broadway

# %%
#Group by pickup and dropoff location
df_network=df.groupby(['pick','dropoff']).mean()[['distance','fare_amount']]
df_network.reset_index(inplace=True)

# %%
#Generating the graph from pandas dataset
G=nx.from_pandas_edgelist(df_network,source='pick',target='dropoff',edge_attr=['distance','fare_amount'],create_using=nx.DiGraph())

# %%
nx.info(G)
# Out:
# 'DiGraph with 3257 nodes and 2069 edges'

# %%
#Creating Subgraph of the largest weakly connected components
Gcc = sorted(nx.weakly_connected_components(G), key=len, reverse=True)
G0 = G.subgraph(Gcc[0])

# %%
#Number of Weakly Connected Components
len(Gcc)
# Out:
# 1191

# %%
list(G0.nodes())
# Out:
# ['340 East 34th Street Manhattan Community Board 6',
#  '1126 Park Avenue Manhattan Community Board 8',
#  'Citi Bike - Columbus Av / W 71 St Columbus Avenue Manhattan Community Board 7',
#  '8th Avenue & West 31st Street West 31st Street Chelsea District',
#  '68-06 Woodside Avenue Queens',
#  'Papaya King 179 East 86th Street',
#  '235 East 22nd Street Manhattan Community Board 6',
#  '345 East 84th Street Manhattan Community Board 8',
#  'USPS Park Avenue Manhattan Community Board 8',
#  '46-15 Center Boulevard Long Island City',
#  '655 Madison Avenue Manhattan Community Board 8',
#  'East Tremont Avenue & Arthur Avenue East Tremont Avenue East Tremont',
#  '385 Greenwich Street Manhattan Community Board 1',
#  'East Houston Street & Greene Street West Houston Street Manhattan Community Board 2',
#  'Madison Square Madison Avenue Manhattan Community Board 5',
#  'Holiday Inn Express 538 West 48th Street',
#  'Fulton Street Broadway Manhattan Community Board 1',
#  '137 Hoyt Street Boerum Hill',
#  'American Airlines Theater 227 West 42nd Street',
#  '11 East 85th Street Manhattan Community Board 8',
#  '358 West 38th Street Manhattan Community Board 4',
#  '400 East 59th Street Manhattan Community Board 6',
#  '42-49 77th Street Queens',
#  '90 Park Avenue 90 Park Avenue',
#  '107 East 126th Street East Harlem',
#  '372 West Broadway Manhattan Community Board 2',
#  '101 Park Avenue 101 Park Avenue',
#  'Montrose Avenue Brooklyn Kings County',
#  'Concourse Plaza Garage East 161st Street Bronx County',
#  '34th Street–Herald Square West 32nd Street Chelsea District',
#  '634 Hudson Street Manhattan Community Board 2',
#  '210 West 61st Street Upper West Side',
#  'Prince Street Manhattan Community Board 2 Manhattan',
#  'FDNY Engine 205/Ladder 118 74-76 Middagh Street',
#  'Pennsylvania Station 8th Avenue Chelsea District',
#  '202 West 49th Street Manhattan Community Board 5',
#  '35 West 81st Street Manhattan Community Board 7',
#  '535 5th Avenue Manhattan Community Board 5',
#  '11 East 32nd Street Manhattan Community Board 5',
#  'Citi Bike - 9th Avenue & West 16th Street 9th Avenue Chelsea District',
#  '411 5th Avenue Manhattan Community Board 5',
#  'REI 303 Lafayette Street',
#  'BMW Building 555 West 57th Street',
#  'Route 132-C Bayard Street Manhattan Community Board 3',
#  '75 Central Park West Manhattan Community Board 7',
#  '155 East 49th Street Manhattan Community Board 6',
#  '808 Columbus Avenue Upper West Side',
#  '241 West 14th Street Chelsea District',
#  'Midtown Manhattan New York County',
#  '153 West 56th Street Manhattan Community Board 5',
#  'Mary Manning Walsh Home 1339 York Avenue',
#  'Warren Street Tribeca Manhattan',
#  'Salmon Tower 11 West 42nd Street',
#  '23rd Street (PATH to New Jersey) West 23rd Street Chelsea District',
#  '240 East 27th Street Manhattan Community Board 6',
#  '347 East 9th Street Manhattan Community Board 3',
#  '777 Sixth Avenue 777 6th Avenue',
#  'Tribeca Park Chambers Street Manhattan Community Board 1',
#  'The Pod Hotel 230 East 51st Street',
#  'New York University Bond Street Manhattan Community Board 2',
#  '217 West 84th Street Upper West Side',
#  'Permanent Mission of the Republic of Palau to the United Nations 866 1st Avenue',
#  '599 1st Avenue Murray Hill',
#  '59th Street - Columbus Circle (1) Broadway Manhattan Community Board 4',
#  '2001 Broadway Upper West Side',
#  'IRT Substation #42 152 East 57th Street',
#  '228 2nd Avenue Manhattan Community Board 3',
#  '1st Avenue Service Road Stuy Town Manhattan',
#  'Adopt a Child 1962 Madison Avenue',
#  'Coogan Building West 26th Street Manhattan Community Board 5',
#  'New Concourse E Terminal C Arrivals Queens',
#  'The New York Times Building 620 8th Avenue',
#  '3 Crosby Street Manhattan Community Board 2',
#  '26 West 56th Street Manhattan Community Board 5',
#  '641 Lexington Avenue 641 Lexington Avenue',
#  '111 East 73rd Street Lenox Hill',
#  '451 Tenth Avenue 451 10th Avenue',
#  'Rothmans 222 Park Avenue South',
#  'Greenberg Hall 545 1st Avenue',
#  'Baita by Birreria 200 5th Avenue',
#  'Woodbridge Hall 431 Riverside Drive',
#  'Le Premier 112 West 56th Street',
#  '67 Irving Place Manhattan Community Board 5',
#  '10th Avenue & West 45th Street 10th Avenue Manhattan Community Board 4',
#  '1468 Madison Avenue Manhattan Community Board 11',
#  '2 Av/E 64 St 2nd Avenue Manhattan Community Board 8',
#  '647 Hudson Street Manhattan Community Board 2',
#  'Santa Fe Veracruzano 62 7th Avenue',
#  '2 Central Park South Manhattan Community Board 5',
#  'Aloft 450 11th Avenue',
#  '913 Cross Bay Boulevard Broad Channel',
#  'Bartholomew Building East 42nd Street Midtown East',
#  'Public School 137 South Street Manhattan Community Board 3',
#  'Broadway & West 120th Street Broadway Manhattan Community Board 9',
#  'West 66th Street & Broadway West 66th Street Upper West Side',
#  'Canal Street Centre Street Manhattan Community Board 2',
#  '7 East 12th Street Manhattan Community Board 2',
#  '403 Greenwich Street Manhattan Community Board 1',
#  '174 1st Avenue Manhattan Community Board 3',
#  '399 Park Avenue 399 Park Avenue',
#  'Beacon Mews 34 West 139th Street',
#  '570 5th Avenue Manhattan Community Board 5',
#  '86 Madison Avenue Manhattan Community Board 5',
#  '8th Avenue Chelsea Manhattan',
#  '128 East 58th Street Manhattan Community Board 5',
#  '156 East 64th Street Manhattan Community Board 8',
#  '49 St Deli & Coffee House 682 11th Avenue',
#  '86th Street 2nd Avenue Manhattan Community Board 8',
#  '38 West 21st Street Manhattan Community Board 5',
#  'Public School-Intermediate School 89 201 Warren Street',
#  '181 West 10th Street Manhattan Community Board 2',
#  'Morgan Stanley Building 1585 Broadway',
#  'West 65th Street Substation West End Avenue Upper West Side',
#  '201 West 34th Street Manhattan Community Board 5',
#  '412 Audubon Avenue Manhattan Community Board 12',
#  'Citibank East 15th Street Manhattan Community Board 6',
#  '3 West 18th Street Manhattan Community Board 5',
#  '1039 5th Avenue Manhattan Community Board 8',
#  '590 5th Avenue Manhattan Community Board 5',
#  'River House East 52nd Street Manhattan Community Board 6',
#  'One Penn Plaza 1 Pennsylvania Plaza',
#  '147 West 66th Street Upper West Side',
#  '432 Amsterdam Avenue Manhattan Community Board 7',
#  'Empire State Building 350 5th Avenue',
#  'Park Avenue & East 18th Street Park Avenue South Manhattan Community Board 5',
#  '261 West 36th Street Garment District',
#  '445 Park Avenue 445 Park Avenue',
#  'The Evelyn Columbus Avenue Manhattan Community Board 7',
#  'PNC Bank West 31st Street Chelsea District',
#  '165 Grand Street Manhattan Community Board 2',
#  'Park Avenue Plaza 55 East 52nd Street',
#  '425 Riverside Drive Manhattan Community Board 9',
#  '1264 River Avenue High Bridge',
#  'Citi Bike - East 32nd Street & Park Avenue East 32nd Street Midtown South',
#  '432 Park Avenue 432 Park Avenue',
#  '1981 1st Avenue Manhattan Community Board 11',
#  '61 West 9th Street Washington Square Village',
#  '850 Third Avenue 850 3rd Avenue',
#  'Bella Union East 29th Street Manhattan Community Board 6',
#  '33 East 65th Street Manhattan Community Board 8',
#  'EHS 1760 Third Avenue 1760 3rd Avenue',
#  '159 East 55th Street Manhattan Community Board 6',
#  'FDR Drive Yorkville Manhattan',
#  '348 West 49th Street Manhattan Community Board 4',
#  '111 East Houston Street Manhattan Community Board 3',
#  '1 Lincoln Plaza 1 West 64th Street',
#  '892 2nd Avenue Manhattan Community Board 6',
#  'Hudson Street & Perry Street Hudson Street Manhattan Community Board 2',
#  "Clem's 264 Grand Street",
#  '420 East 79th Street Manhattan Community Board 8',
#  '203 West 14th Street Manhattan Community Board 4',
#  '120BR-0052 3rd Avenue Manhattan Community Board 8',
#  'The Sofia 43 West 61st Street',
#  'Bowling Green Battery Place Financial District',
#  'Grand Central Terminal Park Avenue Manhattan Community Board 5',
#  'Innside New York Nomad 132 West 27th Street',
#  'UBS Building 1285 6th Avenue',
#  '1947 Adam Clayton Powell Jr. Boulevard Manhattan Community Board 10',
#  "Dunkin' East 97th Street Manhattan Community Board 11",
#  'Gemma East 3rd Street Manhattan Community Board 3',
#  '352 East 20th Street Manhattan Community Board 6',
#  'Wine & Spirits Market 676 6th Avenue',
#  'Alo Yoga 96 Spring Street',
#  'Goldman Sachs Tower 200 West Street',
#  '1 West Street Financial District',
#  '200 East 76th Street Lenox Hill',
#  'East 79th Street & 3rd Avenue East 79th Street Upper East Side',
#  '19 East 88th Street Manhattan Community Board 8',
#  '137 Lexington Avenue Manhattan Community Board 6',
#  '264 5th Avenue Manhattan Community Board 5',
#  'Financial Times Building 1330 6th Avenue',
#  'Bed Bath & Beyond 1932 Broadway',
#  '220 Avenue A Alphabet City',
#  '177 South 4th Street Williamsburg',
#  '578 5th Avenue Manhattan Community Board 5',
#  '189 Bedford Avenue Greenpoint',
#  '88 West End Avenue Upper West Side',
#  '362 5th Avenue Manhattan Community Board 5',
#  '269 Jericho Turnpike Village of Floral Park',
#  "Saint Patrick's Old Cathedral Mulberry Street Manhattan Community Board 2",
#  '160 1st Avenue Manhattan Community Board 3',
#  "East 8th Street / Saint Mark's Place East Village Manhattan",
#  'Sherry Netherlands East 59th Street Upper East Side',
#  '922 3rd Avenue Manhattan Community Board 6',
#  'General Telephone Building 3rd Avenue Manhattan Community Board 6',
#  '720 2nd Avenue Manhattan Community Board 6',
#  '153 East 99th Street Manhattan Community Board 11',
#  '107 West 86th Street Manhattan Community Board 7',
#  '469 7th Avenue Manhattan Community Board 5',
#  'Citigroup Center 3rd Avenue Manhattan Community Board 6',
#  '100 University Place Washington Square Village',
#  '1102 1st Avenue Manhattan Community Board 8',
#  'Port Authority Bus Terminal 625 8th Avenue',
#  '500 West 46th Street Manhattan Community Board 4',
#  '143 Bleecker Street Washington Square Village',
#  'Avalon West Chelsea 282 11th Avenue',
#  'Chambers Street–World Trade Center–Park Place–Cortlandt Street Broadway Manhattan Community Board 1',
#  '383 1st Avenue Manhattan Community Board 6',
#  '305 East 63rd Street Manhattan Community Board 8',
#  'Moma Design Store 81 Spring Street',
#  'Cafefornia 360 Myrtle Avenue',
#  "D'Agostino East 38th Street Manhattan Community Board 6",
#  'Columbus Avenue Upper West Side Manhattan',
#  "Bloomingdale's 1000 3rd Avenue",
#  '114 Rivington Street Manhattan Community Board 3',
#  '117 East 80th Street Upper East Side',
#  'Dante Alighieri West 63rd Street Manhattan Community Board 7',
#  '770 Madison Avenue Manhattan Community Board 8',
#  '1106 5th Avenue Manhattan Community Board 8',
#  'Houston Street Varick Street University Village',
#  '435 Hudson Street University Village',
#  'John F. Kennedy International Airport JFK Access Road Queens',
#  '66 3rd Avenue Manhattan Community Board 3',
#  'Heavenly Market & Deli East 11th Street Manhattan Community Board 3',
#  'The Astor 230 West 76th Street',
#  '810 Seventh Avenue West 53rd Street Manhattan Community Board 5',
#  'Terminal 7 Terminal 7 Departures Queens',
#  '332 East 76th Street Lenox Hill',
#  '181 East Houston Street Manhattan Community Board 3',
#  'Copernicus International School 11-43 47th Avenue',
#  'Truffles Tribeca West Street Manhattan Community Board 1',
#  '233 East 124th Street East Harlem',
#  '304 East 62nd Street Manhattan Community Board 8',
#  '205 Worth Street Lower Manhattan']

# %%
#Number of Nodes in the largest Weakly Connected Component
G0.number_of_nodes()
# Out:
# 224

# %%
#Number of Edges in the largest Weakly Connnected Component
G0.number_of_edges()
# Out:
# 226

# %%
plt.figure(figsize=(30,40))
nx.draw(G0,with_labels=True)
plt.tight_layout()
# Out:
# C:\Users\nilch\AppData\Local\Temp\ipykernel_85680\1707374378.py:3: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
#Neighbours of Grand Central Terminal, Park Avenue
list(G0.neighbors('Grand Central Terminal Park Avenue Manhattan Community Board 5'))
# Out:
# ['1 West Street Financial District',
#  '107 East 126th Street East Harlem',
#  '153 East 99th Street Manhattan Community Board 11',
#  '181 West 10th Street Manhattan Community Board 2',
#  '59th Street - Columbus Circle (1) Broadway Manhattan Community Board 4',
#  '647 Hudson Street Manhattan Community Board 2',
#  '67 Irving Place Manhattan Community Board 5',
#  '850 Third Avenue 850 3rd Avenue',
#  '892 2nd Avenue Manhattan Community Board 6',
#  '922 3rd Avenue Manhattan Community Board 6',
#  'Cafefornia 360 Myrtle Avenue',
#  'Dante Alighieri West 63rd Street Manhattan Community Board 7',
#  'East 79th Street & 3rd Avenue East 79th Street Upper East Side',
#  'East Tremont Avenue & Arthur Avenue East Tremont Avenue East Tremont',
#  'Financial Times Building 1330 6th Avenue',
#  'Fulton Street Broadway Manhattan Community Board 1',
#  'Grand Central Terminal Park Avenue Manhattan Community Board 5',
#  'Heavenly Market & Deli East 11th Street Manhattan Community Board 3',
#  'Morgan Stanley Building 1585 Broadway',
#  'Papaya King 179 East 86th Street',
#  'Santa Fe Veracruzano 62 7th Avenue']

# %%
#Minimum Vertex Cover
def MinimumVertexCover(G):
    
    prob=LpProblem("MinimuVertexcoversize",LpMinimize)
    
    a=LpVariable.dicts("X",G.nodes(),cat="Binary")
    b=LpVariable.dicts("Y",G.edges(),cat="Binary")
    
    
    #Constraints for each edge between the nodes in graph
    for (i,j) in G.edges(): 
        prob += a[i]+a[j]>=1     #Constraint for each edge there is a minimum one node touching it the vertex cover
        prob += b[(i,j)]<=a[j]   
        prob += b[(i,j)]<=1-a[i]
       
    
    #Objective function
    prob += lpSum(a)  #Minimizing the sum of all the vertex
    
    l=[]
    prob.solve()
    print("The minimum number of nodes to cover all the edges in the connected graphs is:",prob.objective.value())
    for v in prob.variables():
        if v.varValue==1:
            l.append(v.name)
    return l

# %%
#Minimum vertex cover of the largest connected component
l=MinimumVertexCover(G0)  #List to store all the nodes in the vertex cover
list_vertex_cover=[]
for i in range(len(l)):
    list_vertex_cover.append(l[i].replace("_"," ")[2:])
pd.Series(list_vertex_cover) #The list of locations that cover all the routes
# Out:
# The minimum number of nodes to cover all the edges in the connected graphs is: 52.0
# 0        100 University Place Washington Square Village
# 1                       111 East 73rd Street Lenox Hill
# 2     111 East Houston Street Manhattan Community Bo...
# 3       11 East 85th Street Manhattan Community Board 8
# 4      153 West 56th Street Manhattan Community Board 5
# 5      155 East 49th Street Manhattan Community Board 6
# 6      156 East 64th Street Manhattan Community Board 8
# 7      235 East 22nd Street Manhattan Community Board 6
# 8     23rd Street (PATH to New Jersey) West 23rd Str...
# 9                 261 West 36th Street Garment District
# 10     305 East 63rd Street Manhattan Community Board 8
# 11                      332 East 76th Street Lenox Hill
# 12     345 East 84th Street Manhattan Community Board 8
# 13     348 West 49th Street Manhattan Community Board 4
# 14    34th Street–Herald Square West 32nd Street Che...
# 15                      399 Park Avenue 399 Park Avenue
# 16     403 Greenwich Street Manhattan Community Board 1
# 17                      432 Park Avenue 432 Park Avenue
# 18           535 5th Avenue Manhattan Community Board 5
# 19    59th Street   Columbus Circle (1) Broadway Man...
# 20        647 Hudson Street Manhattan Community Board 2
# 21        86 Madison Avenue Manhattan Community Board 5
# 22    86th Street 2nd Avenue Manhattan Community Boa...
# 23                         8th Avenue Chelsea Manhattan
# 24                        90 Park Avenue 90 Park Avenue
# 25                  Avalon West Chelsea 282 11th Avenue
# 26    Bartholomew Building East 42nd Street Midtown ...
# 27                     Beacon Mews 34 West 139th Street
# 28    Bella Union East 29th Street Manhattan Communi...
# 29                       Bloomingdale's 1000 3rd Avenue
# 30    Chambers Street–World Trade Center–Park Place–...
# 31    Citigroup Center 3rd Avenue Manhattan Communit...
# 32                        FDR Drive Yorkville Manhattan
# 33             Financial Times Building 1330 6th Avenue
# 34    Fulton Street Broadway Manhattan Community Boa...
# 35    General Telephone Building 3rd Avenue Manhatta...
# 36    Grand Central Terminal Park Avenue Manhattan C...
# 37      Houston Street Varick Street University Village
# 38    John F. Kennedy International Airport JFK Acce...
# 39                    Midtown Manhattan New York County
# 40           New Concourse E Terminal C Arrivals Queens
# 41    New York University Bond Street Manhattan Comm...
# 42     Pennsylvania Station 8th Avenue Chelsea District
# 43           Port Authority Bus Terminal 625 8th Avenue
# 44    Prince Street Manhattan Community Board 2 Manh...
# 45    River House East 52nd Street Manhattan Communi...
# 46    Saint Patrick's Old Cathedral Mulberry Street ...
# 47    The Evelyn Columbus Avenue Manhattan Community...
# 48           The New York Times Building 620 8th Avenue
# 49                        The Sofia 43 West 61st Street
# 50    Tribeca Park Chambers Street Manhattan Communi...
# 51                 Wine & Spirits Market 676 6th Avenue
# dtype: object

# %%
def BellmanFord(G,s,k): #k is the edge_weight- distance/fare_amount
    V=len(G)   #Number of Nodes present in G
    dist=dict(G.nodes) #Distance dictionary to return distance of each node from source node
    for i in dist:
        dist[i]=float(np.inf) # Initialising all the distance from source 's' as infinity
    dist[s]=0.0        
    dict_parents=dict(G.nodes) #Parent dictionary
    for (u,v) in list(G.edges): #Iterating over edges
        if dist[u] != float("Inf") and dist[v]>dist[u]+G[u][v][k]: #Checking if the initial distance is greater 
            dist[v]=dist[u]+G[u][v][k]
            dict_parents[v]=u  #Assigning the parents
        else:
            dict_parents[u]=None  
    #Checking for negative cycle     
    for (u,v) in list(G.edges):
        if dist[u] != float("Inf") and dist[v]>dist[u]+G[u][v][k]:
            dist[v]=np.inf 
                
    sorted_values = sorted(dist.values()) # Sort the values
    sorted_dict = {}

    for i in sorted_values:
        for j in dist.keys():
            if dist[j] == i:
                sorted_dict[j] = dist[j]
    df_bellman=pd.DataFrame(sorted_dict.keys(),sorted_dict.values()).reset_index()
    df_bellman.rename({'index':k,0:'dropoff_location'},axis=1,inplace=True)
    df_bellman=df_bellman[df_bellman[k]!=np.inf]
    
    return df_bellman

# %%
#Shortest path Based on distance(to find the minimum distance in miles)
BellmanFord(G0,'Grand Central Terminal Park Avenue Manhattan Community Board 5','distance')
# Out:
#     distance                                   dropoff_location
# 0   0.000000  Grand Central Terminal Park Avenue Manhattan C...
# 1   0.361334                    850 Third Avenue 850 3rd Avenue
# 2   0.449345         892 2nd Avenue Manhattan Community Board 6
# 3   0.631652           Financial Times Building 1330 6th Avenue
# 4   0.632547              Morgan Stanley Building 1585 Broadway
# 5   0.677729         922 3rd Avenue Manhattan Community Board 6
# 6   1.150330  59th Street - Columbus Circle (1) Broadway Man...
# 7   1.271566        67 Irving Place Manhattan Community Board 5
# 8   1.320024  Dante Alighieri West 63rd Street Manhattan Com...
# 9   1.627706  East 79th Street & 3rd Avenue East 79th Street...
# 10  1.711833      647 Hudson Street Manhattan Community Board 2
# 11  1.732697  Heavenly Market & Deli East 11th Street Manhat...
# 12  1.847338                   Papaya King 179 East 86th Street
# 13  2.008945   181 West 10th Street Manhattan Community Board 2
# 14  2.613963  153 East 99th Street Manhattan Community Board 11
# 15  3.389166  Fulton Street Broadway Manhattan Community Boa...
# 16  3.979652                  107 East 126th Street East Harlem
# 17  4.104700                       Cafefornia 360 Myrtle Avenue
# 18  4.106360                   1 West Street Financial District
# 19  5.419809                 Santa Fe Veracruzano 62 7th Avenue
# 20  6.638544                      1264 River Avenue High Bridge
# 21  7.716762  East Tremont Avenue & Arthur Avenue East Tremo...

# %%
#Shortest path based on fare_amount(to determine the minimum fare for the trip)
BellmanFord(G0,'Grand Central Terminal Park Avenue Manhattan Community Board 5','fare_amount')
# Out:
#     fare_amount                                   dropoff_location
# 0          0.00  Grand Central Terminal Park Avenue Manhattan C...
# 1          4.50           Financial Times Building 1330 6th Avenue
# 2          5.00                 Santa Fe Veracruzano 62 7th Avenue
# 3          6.00                       Cafefornia 360 Myrtle Avenue
# 4          6.50         922 3rd Avenue Manhattan Community Board 6
# 5          6.50  Dante Alighieri West 63rd Street Manhattan Com...
# 6          7.00  East Tremont Avenue & Arthur Avenue East Tremo...
# 7          8.50  Fulton Street Broadway Manhattan Community Boa...
# 8          8.50      647 Hudson Street Manhattan Community Board 2
# 9          9.00  Heavenly Market & Deli East 11th Street Manhat...
# 10        10.00                    850 Third Avenue 850 3rd Avenue
# 11        10.00  East 79th Street & 3rd Avenue East 79th Street...
# 12        10.00  153 East 99th Street Manhattan Community Board 11
# 13        10.50  59th Street - Columbus Circle (1) Broadway Man...
# 14        12.00                  107 East 126th Street East Harlem
# 15        14.50   181 West 10th Street Manhattan Community Board 2
# 16        15.00                   1 West Street Financial District
# 17        15.50                   Papaya King 179 East 86th Street
# 18        16.00                      1264 River Avenue High Bridge
# 19        17.00         892 2nd Avenue Manhattan Community Board 6
# 20        17.50        67 Irving Place Manhattan Community Board 5
# 21        22.66              Morgan Stanley Building 1585 Broadway

# %%
#Merging the two dataset
df_distance_fare_grand_central=pd.merge(right=BellmanFord(G0, 'Grand Central Terminal Park Avenue Manhattan Community Board 5','fare_amount'),left=BellmanFord(G0,'Grand Central Terminal Park Avenue Manhattan Community Board 5','distance'),how='left',on='dropoff_location')

# %%
#Creating fare_per_mile column
df_distance_fare_grand_central['fare_per_mile']=df_distance_fare_grand_central['fare_amount']/df_distance_fare_grand_central['distance']

# %%
#Final Result
df_distance_fare_grand_central.sort_values(by='fare_per_mile',ascending=False).dropna()
# Out:
#     distance                                   dropoff_location  fare_amount  \
# 2   0.449345         892 2nd Avenue Manhattan Community Board 6        17.00
# 4   0.632547              Morgan Stanley Building 1585 Broadway        22.66
# 1   0.361334                    850 Third Avenue 850 3rd Avenue        10.00
# 7   1.271566        67 Irving Place Manhattan Community Board 5        17.50
# 5   0.677729         922 3rd Avenue Manhattan Community Board 6         6.50
# 6   1.150330  59th Street - Columbus Circle (1) Broadway Man...        10.50
# 12  1.847338                   Papaya King 179 East 86th Street        15.50
# 13  2.008945   181 West 10th Street Manhattan Community Board 2        14.50
# 3   0.631652           Financial Times Building 1330 6th Avenue         4.50
# 9   1.627706  East 79th Street & 3rd Avenue East 79th Street...        10.00
# 11  1.732697  Heavenly Market & Deli East 11th Street Manhat...         9.00
# 10  1.711833      647 Hudson Street Manhattan Community Board 2         8.50
# 8   1.320024  Dante Alighieri West 63rd Street Manhattan Com...         6.50
# 14  2.613963  153 East 99th Street Manhattan Community Board 11        10.00
# 18  4.106360                   1 West Street Financial District        15.00
# 16  3.979652                  107 East 126th Street East Harlem        12.00
# 15  3.389166  Fulton Street Broadway Manhattan Community Boa...         8.50
# 20  6.638544                      1264 River Avenue High Bridge        16.00
# 17  4.104700                       Cafefornia 360 Myrtle Avenue         6.00
# 19  5.419809                 Santa Fe Veracruzano 62 7th Avenue         5.00
# 21  7.716762  East Tremont Avenue & Arthur Avenue East Tremo...         7.00
#
#     fare_per_mile
# 2       37.832819
# 4       35.823412
# 1       27.675256
# 7       13.762559
# 5        9.590847
# 6        9.127816
# 12       8.390452
# 13       7.217719
# 3        7.124174
# 9        6.143614
# 11       5.194214
# 10       4.965437
# 8        4.924154
# 14       3.825609
# 18       3.652871
# 16       3.015339
# 15       2.507992
# 20       2.410167
# 17       1.461739
# 19       0.922542
# 21       0.907116
